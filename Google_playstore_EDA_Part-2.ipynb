# %%
"""Import Library"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
clean_df= pd.read_csv("/Users/yogendrasingh/Downloads/Pipeline_ML/clean_googleplaystore.csv")

# %%
# clean_df=clean_df.drop("Unnamed:",axis=1)

# %%
clean_df.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14000.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510   8700.0   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644  25000.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967   2800.0    100000  Free    0.0
#
#   Content Rating                     Genres Last Updated         Current Ver  \
# 0       Everyone               Art & Design   2018-01-07               1.0.0
# ...

# %%
#las five row
clean_df.tail()
# Out:
#        Unnamed: 0                                            App  \
# 10835       10836                               Sya9a Maroc - FR
# 10836       10837               Fr. Mike Schmitz Audio Teachings
# 10837       10838                         Parkinson Exercices FR
# 10838       10839                  The SCP Foundation DB fr nn5n
# 10839       10840  iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Rating  Reviews     Size  Installs  Type  Price  \
# 10835               FAMILY     4.5       38  53000.0      5000  Free    0.0
# 10836               FAMILY     5.0        4   3600.0       100  Free    0.0
# 10837              MEDICAL     NaN        3   9500.0      1000  Free    0.0
# 10838  BOOKS_AND_REFERENCE     4.5      114      NaN      1000  Free    0.0
# 10839            LIFESTYLE     4.5   398307  19000.0  10000000  Free    0.0
#
#       Content Rating             Genres Last Updated         Current Ver  \
# ...

# %%
#random sample from dataset
clean_df.sample(4)
# Out:
#       Unnamed: 0                                               App Category  \
# 627          627                                CAM5678 Video Chat   DATING
# 487          487           Casual Dating & Adult Singles - Joyride   DATING
# 9756        9756  Spinal Cord Surgery Doctor: Operation ER surgery   FAMILY
# 9410        9410                                   EI HabitTracker   FAMILY
#
#       Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# 627      NaN        0  39000.0       500  Free    0.0     Mature 17+
# 487      4.5    61637  11000.0   5000000  Free    0.0     Mature 17+
# 9756     3.7       52  32000.0     10000  Free    0.0   Everyone 10+
# 9410     NaN        2    981.0       100  Free    0.0       Everyone
#
#             Genres Last Updated  Current Ver Android Ver
# 627         Dating   2018-07-13        5.5.8       4.0.3
# 487         Dating   2018-07-31       4.17.2         4.1
# 9756  Role Playing   2018-02-26          1.0         4.1
# ...

# %%
#shape
clean_df.shape
# Out:
# (10840, 14)

# %%
#info about data
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      10840 non-null  int64
#  1   App             10840 non-null  object
#  2   Category        10840 non-null  object
#  3   Rating          9366 non-null   float64
#  4   Reviews         10840 non-null  int64
#  5   Size            9145 non-null   float64
#  6   Installs        10840 non-null  int64
#  7   Type            10839 non-null  object
#  8   Price           10840 non-null  float64
#  9   Content Rating  10840 non-null  object
#  10  Genres          10840 non-null  object
#  11  Last Updated    10840 non-null  object
#  12  Current Ver     10832 non-null  object
#  13  Android Ver     10838 non-null  object
# dtypes: float64(3), int64(3), object(8)
# memory usage: 1.2+ MB

# %%
Unnamed:.describe()
# Out:
#          Unnamed: 0       Rating       Reviews           Size      Installs  \
# count  10840.000000  9366.000000  1.084000e+04    9145.000000  1.084000e+04
# mean    5419.533948     4.191757  4.441529e+05   21506.534062  1.546434e+07
# std     3129.439605     0.515219  2.927761e+06   22596.020795  8.502936e+07
# min        0.000000     1.000000  0.000000e+00      10.000000  0.000000e+00
# 25%     2709.750000     4.000000  3.800000e+01    4900.000000  1.000000e+03
# 50%     5419.500000     4.300000  2.094000e+03   13000.000000  1.000000e+05
# 75%     8129.250000     4.500000  5.477550e+04   30000.000000  5.000000e+06
# max    10840.000000     5.000000  7.815831e+07  100000.000000  1.000000e+09
#
#               Price
# count  10840.000000
# mean       1.027368
# std       15.949703
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      400.000000

# %%
clean_df.columns
# Out:
# Index(['Unnamed: 0', 'App', 'Category', 'Rating', 'Reviews', 'Size',
#        'Installs', 'Type', 'Price', 'Content Rating', 'Genres', 'Last Updated',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
clean_df=clean_df.drop("Unnamed: 0",axis=1)

# %%
clean_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    0.0       Everyone
# 1      967  14000.0    500000  Free    0.0       Everyone
# 2    87510   8700.0   5000000  Free    0.0       Everyone
# 3   215644  25000.0  50000000  Free    0.0           Teen
# 4      967   2800.0    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver
# 0               Art & Design   2018-01-07               1.0.0       4.0.3
# ...

# %%
clean_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10835    False
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# Length: 10840, dtype: bool

# %%
#checking duplicates rows
clean_df[clean_df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
#checking duplicates for particular columns
clean_df[clean_df.duplicated("Reviews")]
# Out:
#                                           App             Category  Rating  \
# 4       Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN     4.3
# 57                 Extreme Rally Championship    AUTO_AND_VEHICLES     4.2
# 126              Skin Care and Natural Beauty               BEAUTY     NaN
# 134             Lady adviser (beauty, health)               BEAUTY     NaN
# 156    Offline: English to Tagalog Dictionary  BOOKS_AND_REFERENCE     4.7
# ...                                       ...                  ...     ...
# 10834                                FR Forms             BUSINESS     NaN
# 10835                        Sya9a Maroc - FR               FAMILY     4.5
# 10836        Fr. Mike Schmitz Audio Teachings               FAMILY     5.0
# 10837                  Parkinson Exercices FR              MEDICAL     NaN
# 10838           The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE     4.5
#
#        Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
#droping these duplicated values [for app column] #keep='first' means we want to keep first ocurrance and rest drop

clean_df=clean_df.drop_duplicates("App", keep="first")

# %%
clean_df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
clean_df.shape
# Out:
# (9659, 13)

# %%
for col in clean_df:
    print(f"{col}:{clean_df[col].value_counts(normalize=True)*100}")
    print("++++++++++++++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# App:Photo Editor & Candy Camera & Grid & ScrapBook    0.010353
# Tic Tac CK                                        0.010353
# INFAMY RO                                         0.010353
# CK Call NEW                                       0.010353
# Ck Coif                                           0.010353
#                                                     ...
# Bike Race Free - Top Motorcycle Racing Games      0.010353
# Dance School Stories - Dance Dreams Come True     0.010353
# 3D Bowling                                        0.010353
# Mind Games Pro                                    0.010353
# iHoroscope - 2018 Daily Horoscope & Astrology     0.010353
# Name: App, Length: 9659, dtype: float64
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Category:FAMILY                 18.966767
# GAME                    9.928564
# TOOLS                   8.561963
# BUSINESS                4.348276
# MEDICAL                 4.089450
# PERSONALIZATION         3.892743
# ...

# %%
clean_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
sns.countplot(x=clean_df["App"])
plt.show()
# Out:
# /Users/yogendrasingh/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128214 (\N{OPEN BOOK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yogendrasingh/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 28459 (\N{CJK UNIFIED IDEOGRAPH-6F2B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yogendrasingh/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21654 (\N{CJK UNIFIED IDEOGRAPH-5496}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/yogendrasingh/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 12304 (\N{LEFT BLACK LENTICULAR BRACKET}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
sns.countplot(x=clean_df["Category"].value_counts())
plt.show()

# %%
## most success category in category column

clean_df["Category"].value_counts().plot.pie(y=clean_df["Category"],figsize=(15,9),)
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
#which category has largest number of installation'

df_cat_installs=clean_df.groupby(["Category"])["Installs"].sum().sort_values(ascending=False).reset_index()

# %%
#top 10

df_cat_installs.head(10)
# Out:
#              Category     Installs
# 0                GAME  13878924415
# 1       COMMUNICATION  11038276251
# 2               TOOLS   8001771915
# 3        PRODUCTIVITY   5793091369
# 4              SOCIAL   5487867902
# 5         PHOTOGRAPHY   4649147655
# 6              FAMILY   4427941505
# 7       VIDEO_PLAYERS   3926902720
# 8    TRAVEL_AND_LOCAL   2894887146
# 9  NEWS_AND_MAGAZINES   2369217760

# %%
plt.figure(figsize=(15,9))
sns.barplot(x="Installs",y="Category",data=df_cat_installs,)
plt.show()

# %%
df_cat_App_installs=clean_df.groupby(["Category","App"])["Installs"].sum().sort_values(ascending=False).reset_index()

# %%
df_cat_App_installs
# Out:
#                 Category                            App    Installs
# 0       TRAVEL_AND_LOCAL             Google Street View  1000000000
# 1     NEWS_AND_MAGAZINES                    Google News  1000000000
# 2          COMMUNICATION  Skype - free IM & video calls  1000000000
# 3          VIDEO_PLAYERS                        YouTube  1000000000
# 4          COMMUNICATION             WhatsApp Messenger  1000000000
# ...                  ...                            ...         ...
# 9654    TRAVEL_AND_LOCAL       EG | Explore Folegandros           0
# 9655             MEDICAL                   EP Cook Book           0
# 9656             FINANCE                    Eu sou Rico           0
# 9657              FAMILY     Ain Arabic Kids Alif Ba ta           0
# 9658  NEWS_AND_MAGAZINES              Sweden Newspapers           0
#
# [9659 rows x 3 columns]

# %%
##Game category

df_cat_App_installs[df_cat_App_installs["Category"]=="COMMUNICATION"]
# Out:
#            Category                                 App    Installs
# 2     COMMUNICATION       Skype - free IM & video calls  1000000000
# 4     COMMUNICATION                  WhatsApp Messenger  1000000000
# 6     COMMUNICATION                            Hangouts  1000000000
# 7     COMMUNICATION        Google Chrome: Fast & Secure  1000000000
# 10    COMMUNICATION                               Gmail  1000000000
# ...             ...                                 ...         ...
# 9445  COMMUNICATION  iCluster - The DX-Cluster database          10
# 9463  COMMUNICATION   Best Browser BD social networking          10
# 9527  COMMUNICATION              Of the wall Arapaho bk           5
# 9551  COMMUNICATION                  Test Server SMS FA           5
# 9632  COMMUNICATION                            BA SALES           1
#
# [315 rows x 3 columns]

# %%
df_cat_App_installs[df_cat_App_installs["Category"]=="FAMILY"]
# Out:
#      Category                            App   Installs
# 49     FAMILY               Tom Loves Angela  100000000
# 81     FAMILY              Talking Tom Cat 2  100000000
# 95     FAMILY  Bitmoji – Your Personal Emoji  100000000
# 103    FAMILY                Talking Tom Cat  100000000
# 105    FAMILY         Talking Tom & Ben News  100000000
# ...       ...                            ...        ...
# 9621   FAMILY                       EF First          1
# 9639   FAMILY              Kenny e o Cupcake          1
# 9648   FAMILY      Command & Conquer: Rivals          0
# 9651   FAMILY         AP Series Solution Pro          0
# 9657   FAMILY     Ain Arabic Kids Alif Ba ta          0
#
# [1832 rows x 3 columns]

# %%
df_cat_App_installs[df_cat_App_installs["Category"]!="MEDICAL"]
# Out:
#                 Category                                           App  \
# 0       TRAVEL_AND_LOCAL                            Google Street View
# 1     NEWS_AND_MAGAZINES                                   Google News
# 2          COMMUNICATION                 Skype - free IM & video calls
# 3          VIDEO_PLAYERS                                       YouTube
# 4          COMMUNICATION                            WhatsApp Messenger
# ...                  ...                                           ...
# 9653     PERSONALIZATION  Popsicle Launcher for Android P 9.0 launcher
# 9654    TRAVEL_AND_LOCAL                      EG | Explore Folegandros
# 9656             FINANCE                                   Eu sou Rico
# 9657              FAMILY                    Ain Arabic Kids Alif Ba ta
# 9658  NEWS_AND_MAGAZINES                             Sweden Newspapers
#
#         Installs
# 0     1000000000
# 1     1000000000
# 2     1000000000
# 3     1000000000
# 4     1000000000
# ...

# %%
#how many aaps are there on google play store which got 5 start rating

df_app_rating= clean_df.groupby(["App"])["Rating"].sum().reset_index().sort_values("Rating",ascending=False)

# %%
df_app_rating
# Out:
#                                                    App  Rating
# 2659                         Comunidad De Fe Minitries     5.0
# 8236                                   Tablet Reminder     5.0
# 6644                             Noticias FC Barcelona     5.0
# 8132  Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 2843                 DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ...                                                ...     ...
# 2922                              DK Childcare Centers     0.0
# 6907                         Pediatric Emergency Guide     0.0
# 6914                                     Pekalongan CJ     0.0
# 6917                        Penn State Health OnDemand     0.0
# 0                 "i DT" Fútbol. Todos Somos Técnicos.     0.0
#
# [9659 rows x 2 columns]

# %%
df_app_rating.head(10)
# Out:
#                                                    App  Rating
# 2659                         Comunidad De Fe Minitries     5.0
# 8236                                   Tablet Reminder     5.0
# 6644                             Noticias FC Barcelona     5.0
# 8132  Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 2843                 DC N COMPANY ENTERTAINMENT RADIO!     5.0
# 8151                                      Sway Medical     5.0
# 2823                                        DB Pickles     5.0
# 2819                                           DB HOME     5.0
# 2806                                      D-H Pharmacy     5.0
# 8210         TI-84 CE Graphing Calculator Manual TI 84     5.0

# %%
#app having 5 start rating
df_app_rating[df_app_rating["Rating"]==5.0]
# Out:
#                                                    App  Rating
# 2659                         Comunidad De Fe Minitries     5.0
# 8236                                   Tablet Reminder     5.0
# 6644                             Noticias FC Barcelona     5.0
# 8132  Superheroes, Marvel, DC, Comics, TV, Movies News     5.0
# 2843                 DC N COMPANY ENTERTAINMENT RADIO!     5.0
# ...                                                ...     ...
# 694                      American Girls Mobile Numbers     5.0
# 9394                                         daskal.eu     5.0
# 4652                         Free coupons and vouchers     5.0
# 1630                                      Bk Usha behn     5.0
# 830                            Asha Ek Hope - ALS/ MND     5.0
#
# [271 rows x 2 columns]

# %%
##second way
rating= clean_df[["App","Rating"]]

# %%
rating= rating.sort_values("Rating",ascending=False)

# %%
rating[rating["Rating"]==5.0]
# Out:
#                                                     App  Rating
# 5685                 Jobs in Canada - Emplois au Canada     5.0
# 7164                                     CD CHOICE TUBE     5.0
# 7195                                           CE Smart     5.0
# 7204          TI-84 CE Graphing Calculator Manual TI 84     5.0
# 9341                                           EG India     5.0
# ...                                                 ...     ...
# 2472  NCLEX Multi-topic Nursing Exam Review-Quiz & n...     5.0
# 2477                             Basics of Orthopaedics     5.0
# 2459    Anatomy & Physiology Vocabulary Exam Review App     5.0
# 2458                                    You're an Anime     5.0
# 7881                               CARDIAC CT TECHNIQUE     5.0
#
# [271 rows x 2 columns]

# %%
clean_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
##which category aap user are reviewing the most

cat_rating= clean_df[["Category","App","Reviews"]]
cat_rating=cat_rating.sort_values("Reviews",ascending=False)
cat_rating
# Out:
#              Category                                       App   Reviews
# 2544           SOCIAL                                  Facebook  78158306
# 336     COMMUNICATION                        WhatsApp Messenger  69119316
# 2545           SOCIAL                                 Instagram  66577313
# 335     COMMUNICATION  Messenger – Text and Video Chat for Free  56642847
# 1670             GAME                            Clash of Clans  44891723
# ...               ...                                       ...       ...
# 6225           SPORTS                      BH Bikes GPS Locator         0
# 6880         BUSINESS                            BV Teknisk App         0
# 6153    VIDEO_PLAYERS            BG MUSIC PLAYER - MUSIC PLAYER         0
# 8154  PERSONALIZATION                       Wallpapers CZ 75 85         0
# 8612         BUSINESS                                 DN Snacks         0
#
# [9659 rows x 3 columns]

# %%
cat_rating.head(1)
# Out:
#      Category       App   Reviews
# 2544   SOCIAL  Facebook  78158306
